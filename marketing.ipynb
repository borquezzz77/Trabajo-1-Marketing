# %%
import pandas as pd

# %%
df =  pd.read_csv('data_arriendos_bicicletas.csv')

# %%
df
# Out:
#                 fecha_hora estacion_anio festivo    dia_laboral  \
# 0      2011-11-14 07:00:00      invierno      NO             si
# 1      2011-12-05 19:00:00      invierno      No             si
# 2      2011-12-02 21:00:00        invier      NO             Si
# 3      2011-11-05 19:00:00      Invierno       N  Fin de semana
# 4      2011-09-10 22:00:00         Otoño      no              N
# ...                    ...           ...     ...            ...
# 10906  2012-01-14 02:00:00          Prim     no               0
# 10907  2011-12-10 09:00:00           Inv       0             No
# 10908  2011-12-18 16:00:00           Inv     no   Fin de semana
# 10909  2011-02-19 07:00:00     Primavera      NO              0
# 10910  2012-05-02 07:00:00           Ver      NO             si
#
#                       clima  temperatura  sensacion_termica  humedad  \
# 0                 DESPEJADO        18.04             21.970     72.0
# ...
